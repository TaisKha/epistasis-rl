# %% [markdown]
# ## 1 CPU CORE

# %%
import os
import numpy as np

amount_of_data = 1000
# random_sim_idx = np.random.randint(self.AMOUNT_OF_DATA)
for idx in range(amount_of_data):
    filename = f"./epigen/sim/{idx}_1_ASW.json"
    if not os.path.exists(filename):
        os.system(f"cd ./epigen/ && python3 simulate_data.py --sim-ids {idx} --corpus-id 1 --pop ASW --inds 5000 --snps 100 --model models/ext_model.ini")

# %% [markdown]
# ## Multiple CPU cores

# %%
import multiprocessing  # the module we will be using for multiprocessing
import os
import numpy as np

def work(idx):
    
    filename = f"./epigen/sim/{idx}_1_ASW.json"
    if not os.path.exists(filename):
        command = ['cd ./epigen/ && python3']
        os.system(f" simulate_data.py --sim-ids {idx} --corpus-id 1 --pop ASW --inds 5000 --snps 100 --model models/ext_model.ini")
    

    
if __name__ == "__main__":  # Allows for the safe importing of the main module
    print("There are %d CPUs on this machine" % multiprocessing.cpu_count())
    number_processes = multiprocessing.cpu_count() - 2
    pool = multiprocessing.Pool(number_processes)
    total_tasks = 1000
    tasks = range(total_tasks)
    results = pool.map_async(work, tasks)
    pool.close()
    pool.join()
# Out:
# There are 44 CPUs on this machine
# File with index 0 does already existFile with index 12 does already existFile with index 6 does already existFile with index 18 does already exist
# File with index 30 does already existFile with index 24 does already exist
# File with index 13 does already existFile with index 66 does already existFile with index 36 does already exist
# File with index 54 does already exist
# File with index 48 does already existFile with index 90 does already existFile with index 42 does already existFile with index 84 does already exist
# File with index 78 does already existFile with index 72 does already exist
# File with index 102 does already exist
# File with index 1 does already exist
# File with index 60 does already exist
#
#
# File with index 108 does already exist
# File with index 120 does already exist
#
#
#
# File with index 14 does already existFile with index 55 does already existFile with index 43 does already existFile with index 31 does already exist
# File with index 37 does already existFile with index 85 does already existFile with index 79 does already exist
# File with index 73 does already existFile with index 114 does already existFile with index 67 does already exist
#
# File with index 19 does already existFile with index 25 does already existFile with index 91 does already exist
#
#
#
# File with index 138 does already existFile with index 61 does already existFile with index 103 does already existFile with index 96 does already existFile with index 2 does already exist
#
#
# File with index 144 does already existFile with index 150 does already exist
# File with index 126 does already existFile with index 15 does already exist
# File with index 109 does already existFile with index 162 does already existFile with index 156 does already existFile with index 38 does already existFile with index 56 does already existFile with index 80 does already exist
# File with index 7 does already existFile with index 44 does already exist
#
#
# File with index 168 does already existFile with index 32 does already exist
#
# File with index 74 does already exist
#
#
#
# File with index 132 does already existFile with index 198 does already exist
#
# File with index 49 does already exist
#
# File with index 186 does already existFile with index 86 does already existFile with index 104 does already exist
#
#
#
#
# File with index 62 does already existFile with index 68 does already exist
# Creating file with index 216File with index 20 does already exist
# Creating file with index 222File with index 204 does already existFile with index 192 does already existFile with index 92 does already existFile with index 115 does already existFile with index 139 does already existFile with index 234 does already existFile with index 16 does already existFile with index 210 does already existFile with index 26 does already exist
# File with index 97 does already existCreating file with index 246
# File with index 151 does already exist
# Creating file with index 228
#
# File with index 39 does already existFile with index 81 does already exist
# File with index 157 does already existFile with index 57 does already existCreating file with index 240
#
#
#
# File with index 8 does already existFile with index 169 does already existFile with index 145 does already existFile with index 110 does already existFile with index 45 does already exist
#
# File with index 163 does already exist
#
#
#
# File with index 33 does already exist
#
#
# File with index 75 does already exist
#
#
#
# File with index 133 does already exist
#
#
# File with index 3 does already existFile with index 121 does already exist
#
#
# File with index 127 does already exist
# File with index 50 does already existFile with index 199 does already existFile with index 87 does already existFile with index 174 does already exist
# File with index 187 does already exist
# File with index 180 does already exist
# File with index 105 does already exist
#
#
#
#
#
# File with index 69 does already existFile with index 116 does already existFile with index 63 does already existFile with index 93 does already existFile with index 205 does already existFile with index 17 does already existFile with index 21 does already existCreating file with index 235
# Creating file with index 211File with index 27 does already existFile with index 140 does already existFile with index 193 does already existFile with index 98 does already existFile with index 152 does already exist
#
#
# File with index 40 does already exist
# File with index 158 does already exist
#
# File with index 46 does already exist
#
# File with index 58 does already existFile with index 146 does already existFile with index 9 does already existFile with index 34 does already exist
#
#
#
#
#
#
#
#
# File with index 170 does already exist
#
#
#
#
#
# File with index 122 does already existFile with index 111 does already existFile with index 128 does already existFile with index 82 does already exist
# File with index 164 does already existFile with index 188 does already existFile with index 175 does already existFile with index 134 does already existFile with index 51 does already existFile with index 88 does already exist
#
# File with index 64 does already existFile with index 117 does already exist
#
#
#
# File with index 70 does already existFile with index 206 does already existCreating file with index 252File with index 76 does already existFile with index 200 does already existFile with index 22 does already existFile with index 4 does already existFile with index 153 does already exist
# File with index 106 does already exist
#
# File with index 28 does already exist
# File with index 94 does already existFile with index 41 does already exist
#
#
#
#
# File with index 10 does already exist
#
#
#
#
#
#
#
#
# File with index 181 does already exist
#
# File with index 194 does already existFile with index 35 does already exist
# File with index 112 does already existFile with index 123 does already existFile with index 129 does already exist
# File with index 47 does already exist
# File with index 165 does already exist
#
# File with index 89 does already existFile with index 171 does already existFile with index 135 does already existFile with index 207 does already existFile with index 159 does already exist
#
#
#
#
#
#
# File with index 71 does already existFile with index 52 does already existFile with index 29 does already existCreating file with index 258File with index 124 does already existFile with index 201 does already exist
#
# File with index 141 does already existFile with index 83 does already exist
# File with index 147 does already exist
#
# File with index 59 does already existFile with index 5 does already existFile with index 23 does already exist
# File with index 99 does already existFile with index 107 does already exist
# File with index 95 does already exist
# File with index 154 does already existFile with index 176 does already exist
# File with index 189 does already exist
# Creating file with index 270
#
# File with index 276 does already exist
#
#
# File with index 11 does already existFile with index 65 does already existFile with index 118 does already exist
# File with index 77 does already existFile with index 172 does already exist
#
#
#
# File with index 182 does already exist
# Creating file with index 264
# File with index 53 does already exist
#
# File with index 130 does already exist
#
#
# Creating file with index 282File with index 113 does already existFile with index 136 does already exist
# File with index 195 does already existCreating file with index 288
#
# File with index 142 does already existCreating file with index 300File with index 148 does already exist
#
# File with index 177 does already existFile with index 155 does already exist
# Creating file with index 294File with index 160 does already exist
#
# Creating file with index 318
# File with index 166 does already existFile with index 202 does already existFile with index 306 does already existFile with index 190 does already exist
#
# File with index 125 does already exist
# File with index 208 does already existCreating file with index 312
# Creating file with index 324
#
#
#
#
#
#
#
# File with index 183 does already existFile with index 173 does already existCreating file with index 330
# File with index 100 does already exist
#
#
#
#
# Creating file with index 277
#
#
# Creating file with index 342Creating file with index 348File with index 119 does already existCreating file with index 336
#
#
# Creating file with index 354
# File with index 196 does already existFile with index 143 does already existFile with index 149 does already exist
# Creating file with index 360
# File with index 203 does already exist
#
# File with index 137 does already existFile with index 191 does already existFile with index 161 does already exist
# File with index 178 does already exist
# File with index 167 does already existCreating file with index 307
# File with index 131 does already existCreating file with index 366File with index 209 does already existCreating file with index 372
#
#
#
# Creating file with index 378
# File with index 184 does already exist
#
#
#
#
#
#
#
#
# Creating file with index 402File with index 197 does already exist
#
#
#
#
# File with index 101 does already existCreating file with index 396Creating file with index 384Creating file with index 390
# Creating file with index 414
# File with index 185 does already existFile with index 179 does already existCreating file with index 432Creating file with index 426
#
# Creating file with index 408
#
#
#
#
# Creating file with index 420
# Creating file with index 450
# Creating file with index 444
#
# Creating file with index 438Creating file with index 456
#
#
#
# Creating file with index 439
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 438.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/438_1_ASW.json
#
# ############################################################################
# Creating file with index 295
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 294.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/294_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 456.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/456_1_ASW.json
#
# ############################################################################
# Creating file with index 457
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 390.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/390_1_ASW.json
#
# ############################################################################
# Creating file with index 391
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 288.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/288_1_ASW.json
#
# ############################################################################
# Creating file with index 289
# Creating file with index 265
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 264.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/264_1_ASW.json
#
# ############################################################################
#
# Creating file with index 385
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 384.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/384_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 300.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/300_1_ASW.json
#
# ############################################################################
# Creating file with index 301
# Creating file with index 397
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 396.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/396_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 246.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/246_1_ASW.json
#
# ############################################################################
# Creating file with index 247
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 240.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/240_1_ASW.json
#
# ############################################################################
# Creating file with index 241
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 228.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/228_1_ASW.json
#
# ############################################################################
# Creating file with index 229
# Creating file with index 278
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 277.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/277_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 211.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/211_1_ASW.json
#
# ############################################################################
#
# Creating file with index 212
# Creating file with index 427
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 426.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/426_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 444.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/444_1_ASW.json
#
# ############################################################################
# File with index 445 does already exist
# Creating file with index 446
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 354.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/354_1_ASW.json
#
# ############################################################################
# File with index 355 does already exist
# Creating file with index 356
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 222.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/222_1_ASW.json
#
# ############################################################################
# File with index 223 does already exist
# Creating file with index 224
# Creating file with index 349
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 348.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/348_1_ASW.json
#
# ############################################################################
#
# File with index 331 does already exist
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 330.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/330_1_ASW.json
#
# ############################################################################
#
# Creating file with index 332
# Creating file with index 319
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 318.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/318_1_ASW.json
#
# ############################################################################
# Creating file with index 343
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 342.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/342_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 360.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/360_1_ASW.json
#
# ############################################################################
# Creating file with index 361
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 366.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/366_1_ASW.json
#
# ############################################################################
# File with index 367 does already exist
# Creating file with index 368
# Creating file with index 308
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 307.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/307_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 235.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/235_1_ASW.json
#
# ############################################################################
# Creating file with index 236
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 258.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/258_1_ASW.json
#
# ############################################################################
# Creating file with index 259
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 324.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/324_1_ASW.json
#
# ############################################################################
# Creating file with index 325
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 408.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/408_1_ASW.json
#
# ############################################################################
# Creating file with index 409
# Creating file with index 433
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 432.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/432_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 252.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/252_1_ASW.json
#
# ############################################################################
# Creating file with index 253
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 216.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/216_1_ASW.json
#
# ############################################################################
# Creating file with index 217
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 414.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/414_1_ASW.json
#
# ############################################################################
# Creating file with index 415
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 270.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/270_1_ASW.json
#
# ############################################################################
# Creating file with index 271
# File with index 337 does already exist
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 336.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/336_1_ASW.json
#
# ############################################################################
# Creating file with index 338
# Creating file with index 313
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 312.
# ...
# Creating file with index 988
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 987.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/987_1_ASW.json
#
# ############################################################################
# Creating file with index 999
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 998.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/998_1_ASW.json
#
# ############################################################################
# Creating file with index 995
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 994.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/994_1_ASW.json
#
# ############################################################################
# File with index 977 does already exist
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 976.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/976_1_ASW.json
#
# ############################################################################
# Creating file with index 941
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 940.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/940_1_ASW.json
#
# ############################################################################
# Creating file with index 971
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 970.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/970_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 965.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/965_1_ASW.json
#
# ############################################################################
# Creating file with index 953
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 952.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/952_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 999.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/999_1_ASW.json
#
# ############################################################################
# Creating file with index 989
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 988.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/988_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 995.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/995_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 941.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/941_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 971.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/971_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 953.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/953_1_ASW.json
#
# ############################################################################
#
# ############################################################################
# ######################### EpiGEN - simulate_data.py ########################
#
# Loading genotype corpus.
# Genotype corpus contains 116415 SNPs and 10000 individuals.
# Loading SNPs.
# Loading MAFs.
# Loading cumulative MAF distribution.
# Parsing epistasis model.
# Checking input consistency.
# ----------------------------------------------------------------------------
# Starting simulation for simulation ID 989.
# Checking disease MAF range (extend if too narrow).
# Checking noise MAF range (extend if too narrow).
# Sampling disease SNPs.
# Sampling noise SNPs.
# Updating genotype matrix, MAF array, and SNP list.
# Generating the phenotypes.
# Subsampling the individuals.
# Serializing the simulated data.
# ----------------------------------------------------------------------------
# Finished simulation of epistasis data.
# The generated data can be found in the ./sim directory:
# Generated data:	./sim/989_1_ASW.json
#
# ############################################################################
